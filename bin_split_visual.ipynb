# %%
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from matplotlib import pylab as plt
from scipy.cluster.vq import kmeans2

# %%
cd ../assign4/memo/
# Out:
# /Users/herbst/teaching/MachineLearning/2014/assign4/memo

# %%
from gauss import Gauss
from  kmeans import Kmeans
from gmm import Gmm

# %%
data = np.loadtxt('./data/signatures/sign2/sigtrain2_1.txt',comments='%')[:,:2].T
#plt.plot(data[0,:],data[1,:],'.r')
g = Gmm(data,k=7,plot=True)
